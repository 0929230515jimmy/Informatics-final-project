# %%
import pandas as pd
df = pd.read_csv('spreadspoke_scores.csv')

# %%
df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    12/24/1978             1978      Wildcard              True
# 1    12/24/1978             1978      Wildcard              True
# 2    12/30/1978             1978      Division              True
# 3    12/30/1978             1978      Division              True
# 4    12/31/1978             1978      Division              True
#
#              team_home  score_home  score_away            team_away  \
# 0      Atlanta Falcons          14          13  Philadelphia Eagles
# 1       Miami Dolphins           9          17       Houston Oilers
# 2       Dallas Cowboys          27          20      Atlanta Falcons
# 3  Pittsburgh Steelers          33          10       Denver Broncos
# 4     Los Angeles Rams          34          10    Minnesota Vikings
#
#   team_favorite_id  spread_favorite over_under_line  \
# 0              ATL             -2.5             NaN
# 1              MIA             -6.5             NaN
# ...
